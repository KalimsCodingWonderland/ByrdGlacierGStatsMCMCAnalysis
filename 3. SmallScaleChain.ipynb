# %% [markdown]
# # Tutorial 4: Initializing a small-scale chain

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from gstatsMCMC import Topography
from gstatsMCMC import MCMC
import gstatsim as gs
from sklearn.preprocessing import QuantileTransformer
import skgstat as skg

# %%
# load compiled bed elevation measurements
df = pd.read_csv('ByrdGlacierDataGridded.csv')

# %%
# create a grid of x and y coordinates
x_uniq = np.unique(df.x)
y_uniq = np.unique(df.y)

xmin = np.min(x_uniq)
xmax = np.max(x_uniq)
ymin = np.min(y_uniq)
ymax = np.max(y_uniq)

cols = len(x_uniq)
rows = len(y_uniq)

resolution = 500

xx, yy = np.meshgrid(x_uniq, y_uniq)

# %%
# load other data
dhdt = df['dhdt'].values.reshape(xx.shape)
smb = df['smb'].values.reshape(xx.shape)
velx = df['velx'].values.reshape(xx.shape)
vely = df['vely'].values.reshape(xx.shape)
bedmap_mask = df['bedmap_mask'].values.reshape(xx.shape)
bedmachine_thickness = df['bedmachine_thickness'].values.reshape(xx.shape)
bedmap_surf = df['bedmap_surf'].values.reshape(xx.shape)
highvel_mask = df['highvel_mask'].values.reshape(xx.shape)
bedmachine_bed = df['bedmap_surf'].values.reshape(xx.shape) - bedmachine_thickness
bedmap_bed = df['bedmap_bed'].values.reshape(xx.shape)

# %%
# create conditioning data
# bed elevation measurement in grounded ice region, and bedmap topography elsewhere
cond_bed = np.where(bedmap_mask == 1, df['bed'].values.reshape(xx.shape), bedmap_bed)
df['cond_bed'] = cond_bed.flatten()
# create a mask of conditioning data
data_mask = ~np.isnan(cond_bed)

# %% [markdown]
# __step1: calculate the trend__

# %%
initial_bed = np.loadtxt('bedsOG_at_2572000th_iteration')

# %%
import scipy as sp
trend = sp.ndimage.gaussian_filter(initial_bed, sigma=10)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4),gridspec_kw={'width_ratios': [1, 1.3]} )

axes[0].pcolormesh(xx, yy, initial_bed, vmax=1500,vmin=-3500)
axes[0].set_title('initial bed')
axes[0].set_aspect('equal')

bedfig = axes[1].pcolormesh(xx, yy, trend, vmax=1500,vmin=-3500)
axes[1].set_title('topography trend (smoothed initial bed)')
axes[1].set_aspect('equal')
fig.colorbar(bedfig, ax=axes[1])

# %% [markdown]
# __step2: calculate detrended variogram__

# %%
# ##################WHEN NO DETREND###################
# #normalize the conditioning bed data, saved to df['Nbed']
data = df['cond_bed'].values.reshape(-1,1)
nst_trans = QuantileTransformer(n_quantiles=500, output_distribution="normal",random_state=0).fit(data)
transformed_data = nst_trans.transform(data)
df['Nbed'] = transformed_data

# %%
# normalize the de-trended conditioning data, saved to df['Nbed_residual']
df['cond_bed_residual']=df['cond_bed'].values-trend.flatten()
data = df['cond_bed_residual'].values.reshape(-1,1)
nst_trans = QuantileTransformer(n_quantiles=500, output_distribution="normal",random_state=0).fit(data)
transformed_data = nst_trans.transform(data)
df['Nbed_residual'] = transformed_data

# %%
###################WHEN NO DETREND###################
df_sampled = df.sample(frac=0.4, random_state=42)
df_sampled = df_sampled[df_sampled["cond_bed"].isnull() == False]
df_sampled = df_sampled[df_sampled["bedmap_mask"]==1]
coords = df_sampled[['x','y']].values
values = df_sampled['Nbed']

# randomly drop out 50% of coordinates. Decrease this value if you have a lot of data and it takes a long time to run
#df_sampled = df.sample(frac=0.4, random_state=42)
#df_sampled = df_sampled[df_sampled["cond_bed_residual"].isnull() == False]
#df_sampled = df_sampled[df_sampled["bedmap_mask"]==1]

# compute experimental (isotropic) variogram
#coords = df_sampled[['x','y']].values
#values = df_sampled['Nbed_residual']

maxlag = 20000      # maximum range distance
n_lags = 70         # num of bins (try decreasing if this is taking too long)

# compute variogram
V1 = skg.Variogram(coords, values, bin_func='even', n_lags=n_lags, maxlag=maxlag, normalize=False, model='matern')

# extract variogram values
xdata = V1.bins
ydata = V1.experimental

V1_p = V1.parameters

# evaluate models
xi = np.linspace(0, xdata[-1], n_lags) 
y_mtn = [skg.models.matern(h, V1_p[0], V1_p[1], V1_p[2], V1_p[3]) for h in xi]
# variogram parameter is [range, sill, shape, nugget] for matern model.

plt.figure(figsize=(6,4))
plt.scatter(xdata, ydata, s=12, c='g')
plt.plot(xi, y_mtn,'b-.', label='Matern variogram model')
plt.title('Isotropic Experimental Variogram')
plt.xlabel('Lag (m)'); plt.ylabel('Semivariance')
plt.show()

# %%
V1_p
# Out:
# [19999.999999999978, 0.4368743777039384, 0.9112784196971139, 0]

# %%
###################When load sgs-generated bed as initial bed###################
# load the initial bed, make sure no bed in grounded ice region is higher altitude than ice surface
#sgs_bed = np.loadtxt('sgs_bed_totten_cropped.txt')
#thickness = bedmap_surf - sgs_bed
#sgs_bed = np.where((thickness<=0)&(bedmap_mask==1), bedmap_surf-1, sgs_bed)

# %% [markdown]
# ### Then initiating the SGS chain

# %% [markdown]
# The first 4 initialization process are very similar to chain_crf, please refers to Tutorial 3 for detailed information

# %%
grounded_ice_mask = (bedmap_mask == 1)

# %% [markdown]
# step3: set up the chain
# - change initial bed
# - set normal transformation
# - set trend

# %%
###################When start with a sgs-generated bed###################
#smallScaleChain = MCMC.chain_sgs(xx, yy, sgs_bed, bedmap_surf, velx, vely, dhdt, smb, cond_bed, data_mask, grounded_ice_mask, resolution)

# %%
smallScaleChain = MCMC.chain_sgs(xx, yy, initial_bed, bedmap_surf, velx, vely, dhdt, smb, cond_bed, data_mask, grounded_ice_mask, resolution)
# Out:
# before running the chain, please set where the block update will be using the object's function set_update_in_region(region_mask) and set_update_region(update_in_region)
# please also set up the sgs parameters using set_sgs_param(self, block_size, sgs_param)
# then please set up the loss function using either set_loss_type or set_loss_func

# %%
smallScaleChain.set_update_region(True,highvel_mask)
# Out:
# the update blocks is set to be randomly generated for any locations inside the given region

# %%
smallScaleChain.set_loss_type(map_func='sumsquare', sigma_mc=5, massConvInRegion=True)

# %%
# set up the block sizes
min_block_x = 5
max_block_x = 20
min_block_y = 5
max_block_y = 20
smallScaleChain.set_block_sizes(min_block_x, max_block_x, min_block_y, max_block_y)

# %% [markdown]
# Sequential Gaussian Simulation is set to perform on the normalized data. This nst_trans is an object of the QuantileTranformer class in scikit-learn python library. The *fit_variogram* function returns a nst_trans object, which could be directly used here

# %%
###################When no normal score transformation###################
# do_transform could be set to true for both detrend and no detrend options
# recommend to set it to true
#smallScaleChain.set_normal_transformation(nst_trans, do_transform=False)

# %%
smallScaleChain.set_normal_transformation(nst_trans, do_transform=True)

# %% [markdown]
# When running the SGS chain, it is possible to 'detrend' the topography.
#
# Detrend topography refers to substracting a pre-defined trend from the topography map, where the trend suppose to represent long-wavelength features that violate stationary properties of SGS. If choose to detrend the topography, the argument *detrend_map* need to be set to True, and the argument *trend* need to be a 2D numpy array representing the topography trend

# %%
###################WHEN NO DETREND###################
smallScaleChain.set_trend(trend = [], detrend_map = False)

# %%
smallScaleChain.set_trend(trend = trend, detrend_map = True)

# %%
smallScaleChain.set_variogram('Matern',V1_p[0],V1_p[1],0,isotropic=True,vario_smoothness=V1_p[2])
# Out:
# the variogram is set to type Matern

# %%
smallScaleChain.set_sgs_param(48, 30e3, sgs_rand_dropout_on=False)
# Out:
# because the sgs_rand_dropout_on is set to False, the dropout_rate is automatically set to 0

# %% [markdown]
# __step4: run the chain, check if the loss is correct__

# %%
# test the new sgs
beds, loss_mc, loss_data, loss, steps, resampled_times, blocks_used = smallScaleChain.run_newsgs(n_iter=100, only_save_last_bed=True, info_per_iter = 1000)
# Out:
# i: 0 mc loss: 3.631e+05 loss: 3.631e+05 acceptance rate: 0.0

# %%
# test the original sgs
beds, loss_mc, loss_data, loss, steps, resampled_times, blocks_used = smallScaleChain.run_newsgs(n_iter=100, only_save_last_bed=True, info_per_iter = 1000)
# Out:
# i: 0 mc loss: 3.896e+05 loss: 3.896e+05 acceptance rate: 0.0

# %%
plt.pcolormesh(xx,yy,beds,vmax=1500,vmin=-1500)

# %%
n_iter = 1000

for i in range(0,20):
    beds, loss_mc, loss_data, loss, steps, resampled_times, blocks_used = smallScaleChain.run_newsgs(n_iter=n_iter, only_save_last_bed=True, info_per_iter = 200)
    
    # save all the data in every run of the algorithm
    np.savetxt('Byrd_sgs1_loss_'+str(i*n_iter)+'.txt', loss)
    np.savetxt('Byrd_sgs1_steps_'+str(i*n_iter)+'.txt', steps) 
    np.savetxt('Byrd_sgs1_bed_'+str(i*n_iter)+'.txt',beds)
    
    # set up the next chain
    smallScaleChain.initial_bed = beds
# Out:
# i: 0 mc loss: 3.650e+05 loss: 3.650e+05 acceptance rate: 0.0
# i: 200 mc loss: 3.650e+05 loss: 3.650e+05 acceptance rate: 0.0
# i: 400 mc loss: 3.650e+05 loss: 3.650e+05 acceptance rate: 0.0
# i: 600 mc loss: 3.650e+05 loss: 3.650e+05 acceptance rate: 0.0
# i: 800 mc loss: 3.650e+05 loss: 3.650e+05 acceptance rate: 0.011235955056179775
# i: 0 mc loss: 3.650e+05 loss: 3.650e+05 acceptance rate: 0.0
# i: 200 mc loss: 3.650e+05 loss: 3.650e+05 acceptance rate: 0.09950248756218906
# i: 400 mc loss: 3.650e+05 loss: 3.650e+05 acceptance rate: 0.08478802992518704
# i: 600 mc loss: 3.649e+05 loss: 3.649e+05 acceptance rate: 0.08818635607321132
# i: 800 mc loss: 3.649e+05 loss: 3.649e+05 acceptance rate: 0.08489388264669163
# i: 0 mc loss: 3.649e+05 loss: 3.649e+05 acceptance rate: 0.0
# i: 200 mc loss: 3.649e+05 loss: 3.649e+05 acceptance rate: 0.07960199004975124
# i: 400 mc loss: 3.649e+05 loss: 3.649e+05 acceptance rate: 0.0773067331670823
# i: 600 mc loss: 3.649e+05 loss: 3.649e+05 acceptance rate: 0.08319467554076539
# i: 800 mc loss: 3.649e+05 loss: 3.649e+05 acceptance rate: 0.07865168539325842
# i: 0 mc loss: 3.649e+05 loss: 3.649e+05 acceptance rate: 0.0
# i: 200 mc loss: 3.648e+05 loss: 3.648e+05 acceptance rate: 0.0845771144278607
# i: 400 mc loss: 3.648e+05 loss: 3.648e+05 acceptance rate: 0.0773067331670823
# i: 600 mc loss: 3.648e+05 loss: 3.648e+05 acceptance rate: 0.07321131447587355
# i: 800 mc loss: 3.648e+05 loss: 3.648e+05 acceptance rate: 0.07615480649188515
# i: 0 mc loss: 3.648e+05 loss: 3.648e+05 acceptance rate: 0.0
# i: 200 mc loss: 3.648e+05 loss: 3.648e+05 acceptance rate: 0.09950248756218906
# i: 400 mc loss: 3.648e+05 loss: 3.648e+05 acceptance rate: 0.09725685785536159
# i: 600 mc loss: 3.648e+05 loss: 3.648e+05 acceptance rate: 0.09317803660565724
# i: 800 mc loss: 3.647e+05 loss: 3.647e+05 acceptance rate: 0.08489388264669163
# i: 0 mc loss: 3.647e+05 loss: 3.647e+05 acceptance rate: 0.0
# i: 200 mc loss: 3.646e+05 loss: 3.646e+05 acceptance rate: 0.0845771144278607
# i: 400 mc loss: 3.646e+05 loss: 3.646e+05 acceptance rate: 0.07481296758104738
# i: 600 mc loss: 3.646e+05 loss: 3.646e+05 acceptance rate: 0.07820299500831947
# i: 800 mc loss: 3.646e+05 loss: 3.646e+05 acceptance rate: 0.08239700374531835
# i: 0 mc loss: 3.646e+05 loss: 3.646e+05 acceptance rate: 0.0
# i: 200 mc loss: 3.646e+05 loss: 3.646e+05 acceptance rate: 0.09950248756218906
# i: 400 mc loss: 3.646e+05 loss: 3.646e+05 acceptance rate: 0.08478802992518704
# i: 600 mc loss: 3.646e+05 loss: 3.646e+05 acceptance rate: 0.07820299500831947
# i: 800 mc loss: 3.646e+05 loss: 3.646e+05 acceptance rate: 0.06741573033707865
# i: 0 mc loss: 3.645e+05 loss: 3.645e+05 acceptance rate: 0.0
# i: 200 mc loss: 3.645e+05 loss: 3.645e+05 acceptance rate: 0.0945273631840796
# i: 400 mc loss: 3.645e+05 loss: 3.645e+05 acceptance rate: 0.0773067331670823
# i: 600 mc loss: 3.645e+05 loss: 3.645e+05 acceptance rate: 0.07820299500831947
# i: 800 mc loss: 3.645e+05 loss: 3.645e+05 acceptance rate: 0.08489388264669163
# i: 0 mc loss: 3.645e+05 loss: 3.645e+05 acceptance rate: 1.0
# i: 200 mc loss: 3.645e+05 loss: 3.645e+05 acceptance rate: 0.0845771144278607
# i: 400 mc loss: 3.645e+05 loss: 3.645e+05 acceptance rate: 0.0773067331670823
# i: 600 mc loss: 3.644e+05 loss: 3.644e+05 acceptance rate: 0.08153078202995008
# i: 800 mc loss: 3.644e+05 loss: 3.644e+05 acceptance rate: 0.07865168539325842
# i: 0 mc loss: 3.644e+05 loss: 3.644e+05 acceptance rate: 1.0
# i: 200 mc loss: 3.644e+05 loss: 3.644e+05 acceptance rate: 0.0845771144278607
# i: 400 mc loss: 3.644e+05 loss: 3.644e+05 acceptance rate: 0.07231920199501247
# i: 600 mc loss: 3.643e+05 loss: 3.643e+05 acceptance rate: 0.064891846921797
# i: 800 mc loss: 3.643e+05 loss: 3.643e+05 acceptance rate: 0.0686641697877653
# i: 0 mc loss: 3.643e+05 loss: 3.643e+05 acceptance rate: 0.0
# i: 200 mc loss: 3.643e+05 loss: 3.643e+05 acceptance rate: 0.05472636815920398
# i: 400 mc loss: 3.643e+05 loss: 3.643e+05 acceptance rate: 0.05486284289276808
# i: 600 mc loss: 3.641e+05 loss: 3.641e+05 acceptance rate: 0.05490848585690516
# i: 800 mc loss: 3.641e+05 loss: 3.641e+05 acceptance rate: 0.052434456928838954
# i: 0 mc loss: 3.641e+05 loss: 3.641e+05 acceptance rate: 0.0
# i: 200 mc loss: 3.641e+05 loss: 3.641e+05 acceptance rate: 0.04975124378109453
# i: 400 mc loss: 3.641e+05 loss: 3.641e+05 acceptance rate: 0.07481296758104738
# i: 600 mc loss: 3.641e+05 loss: 3.641e+05 acceptance rate: 0.064891846921797
# i: 800 mc loss: 3.641e+05 loss: 3.641e+05 acceptance rate: 0.05742821473158552
# i: 0 mc loss: 3.640e+05 loss: 3.640e+05 acceptance rate: 0.0
# i: 200 mc loss: 3.640e+05 loss: 3.640e+05 acceptance rate: 0.1044776119402985
# i: 400 mc loss: 3.640e+05 loss: 3.640e+05 acceptance rate: 0.0798004987531172
# i: 600 mc loss: 3.639e+05 loss: 3.639e+05 acceptance rate: 0.08153078202995008
# i: 800 mc loss: 3.639e+05 loss: 3.639e+05 acceptance rate: 0.07365792759051186
# i: 0 mc loss: 3.639e+05 loss: 3.639e+05 acceptance rate: 0.0
# i: 200 mc loss: 3.639e+05 loss: 3.639e+05 acceptance rate: 0.1044776119402985
# i: 400 mc loss: 3.639e+05 loss: 3.639e+05 acceptance rate: 0.0773067331670823
# i: 600 mc loss: 3.639e+05 loss: 3.639e+05 acceptance rate: 0.07653910149750416
# i: 800 mc loss: 3.639e+05 loss: 3.639e+05 acceptance rate: 0.06991260923845194
# i: 0 mc loss: 3.639e+05 loss: 3.639e+05 acceptance rate: 0.0
# i: 200 mc loss: 3.639e+05 loss: 3.639e+05 acceptance rate: 0.0845771144278607
# i: 400 mc loss: 3.638e+05 loss: 3.638e+05 acceptance rate: 0.059850374064837904
# i: 600 mc loss: 3.638e+05 loss: 3.638e+05 acceptance rate: 0.064891846921797
# i: 800 mc loss: 3.638e+05 loss: 3.638e+05 acceptance rate: 0.06991260923845194
# i: 0 mc loss: 3.638e+05 loss: 3.638e+05 acceptance rate: 0.0
# i: 200 mc loss: 3.638e+05 loss: 3.638e+05 acceptance rate: 0.06965174129353234
# i: 400 mc loss: 3.638e+05 loss: 3.638e+05 acceptance rate: 0.07231920199501247
# i: 600 mc loss: 3.638e+05 loss: 3.638e+05 acceptance rate: 0.07653910149750416
# i: 800 mc loss: 3.638e+05 loss: 3.638e+05 acceptance rate: 0.07990012484394507
# i: 0 mc loss: 3.637e+05 loss: 3.637e+05 acceptance rate: 0.0
# i: 200 mc loss: 3.638e+05 loss: 3.638e+05 acceptance rate: 0.04975124378109453
# i: 400 mc loss: 3.637e+05 loss: 3.637e+05 acceptance rate: 0.04738154613466334
# i: 600 mc loss: 3.637e+05 loss: 3.637e+05 acceptance rate: 0.05823627287853577
# i: 800 mc loss: 3.637e+05 loss: 3.637e+05 acceptance rate: 0.05867665418227216
# i: 0 mc loss: 3.637e+05 loss: 3.637e+05 acceptance rate: 0.0
# i: 200 mc loss: 3.633e+05 loss: 3.633e+05 acceptance rate: 0.06965174129353234
# i: 400 mc loss: 3.633e+05 loss: 3.633e+05 acceptance rate: 0.07481296758104738
# i: 600 mc loss: 3.633e+05 loss: 3.633e+05 acceptance rate: 0.07487520798668885
# i: 800 mc loss: 3.633e+05 loss: 3.633e+05 acceptance rate: 0.07116104868913857
# i: 0 mc loss: 3.633e+05 loss: 3.633e+05 acceptance rate: 0.0
# i: 200 mc loss: 3.633e+05 loss: 3.633e+05 acceptance rate: 0.03482587064676617
# i: 400 mc loss: 3.633e+05 loss: 3.633e+05 acceptance rate: 0.032418952618453865
# i: 600 mc loss: 3.632e+05 loss: 3.632e+05 acceptance rate: 0.051580698835274545
# i: 800 mc loss: 3.632e+05 loss: 3.632e+05 acceptance rate: 0.062421972534332085
# i: 0 mc loss: 3.632e+05 loss: 3.632e+05 acceptance rate: 0.0
# i: 200 mc loss: 3.632e+05 loss: 3.632e+05 acceptance rate: 0.0945273631840796
# i: 400 mc loss: 3.632e+05 loss: 3.632e+05 acceptance rate: 0.06733167082294264
# i: 600 mc loss: 3.631e+05 loss: 3.631e+05 acceptance rate: 0.06156405990016639
# i: 800 mc loss: 3.632e+05 loss: 3.632e+05 acceptance rate: 0.06367041198501873

# %%
#9197s for 20*1000 iters

# %%
bed1 = np.loadtxt('Byrd_sgs1_bed_1000.txt')
plt.pcolormesh(xx,yy,bed1,vmax=2000,vmin=-2500)
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')
# Out:
# Text(0, 0.5, 'y (m)')

# %%
bed2 = np.loadtxt('Byrd_sgs1_bed_19000.txt')
plt.pcolormesh(xx,yy,bed2,vmax=2000,vmin=-2500)
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')
# Out:
# Text(0, 0.5, 'y (m)')

# %%
plt.pcolormesh(xx,yy,bed2-bed1, cmap='RdBu',vmax=200,vmin=-200)
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')
# Out:
# Text(0, 0.5, 'y (m)')

# %%
plt.pcolormesh(xx,yy,bed2-bed1>1)
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')
# Out:
# Text(0, 0.5, 'y (m)')

# %%
bed2 = np.loadtxt('Byrd_sgs1_bed_19000.txt')
plt.pcolormesh(xx,yy,bed2 - cond_bed,vmax=1,vmin=-1,cmap='RdBu')
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')
# Out:
# Text(0, 0.5, 'y (m)')
